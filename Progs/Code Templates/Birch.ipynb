# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=200, noise=0.1)

# %% [markdown]
# ## Pre-processing

# %%
from sklearn.preprocessing import StandardScaler
stdScaler = StandardScaler()
X = stdScaler.fit_transform(X)

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.title("Given Data")
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# ## Actual Clusters

# %%
plt.scatter(X[y == 0, 0], X[y == 0, 1])
plt.scatter(X[y == 1, 0], X[y == 1, 1])
plt.title("Actual Clusters")
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# # Birch

# %%
from sklearn.cluster import Birch
birch_model = Birch(n_clusters=2, branching_factor=50, threshold=0.5)
y_pred = birch_model.fit_predict(X)
for i in sorted(set(y_pred)) :
    plt.scatter(X[y_pred == i, 0], X[y_pred == i, 1], label = "cluster " + str(i+1))
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Clustering using BIRCH")
plt.legend()
plt.show()
